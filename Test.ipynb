# %% [markdown]
# <a href="https://colab.research.google.com/github/omkar806/on-device-experiments/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 24.4 MB/s eta 0:00:00
# ...

# %%
import pymongo
import pandas as pd
# Replace the URI with your actual MongoDB connection URI
mongo_uri = "mongodb+srv://intern:JeUDstYbGTSczN4r@interntest.i7decv0.mongodb.net/"

# Connect to the MongoDB server
client = pymongo.MongoClient(mongo_uri)
# Get the list of available databases
database_names = client.list_database_names()
db = client['intern']
collection_names = db.list_collection_names()
# Print the available databases
print("Available Databases:")
for db_name in database_names:
    print(db_name)

database_name = 'intern'

# Access the specified database
db = client[database_name]

# Print the available collections
print(f"Available Collections in '{database_name}':")
for collection_name in collection_names:
    print(collection_name)



# Access a collection (replace 'your_collection_name' with the actual collection name)
collection = db['papers']

# Retrieve data from the collection
cursor = collection.find()

# Convert the cursor to a pandas DataFrame
df = pd.DataFrame(list(cursor))

# Save the DataFrame to a CSV file
csv_file_path = 'output_data.csv'
df.to_csv(csv_file_path, index=False)

# Close the MongoDB connection
client.close()
# Out:
# Available Databases:
# intern
# admin
# local
# Available Collections in 'intern':
# papers

# %%
df.head()
# Out:
#                         _id       paperID  \
# 0  654d59e135ea7779e6d7d03c  1711.00661v1
# 1  654d59e135ea7779e6d7d03d  2304.01523v1
# 2  654d59e135ea7779e6d7d03e  2103.07999v1
# 3  654d5b4633e726bca001ec05  2204.05182v1
# 4  654d6c588e6aa6e35e963dae  1712.00674v1
#
#                                             abstract  \
# 0  Startups have become in less than 50 years a m...
# 1  Context: On top of the inherent challenges sta...
# 2  Context: Software startups are an essential so...
# 3  Analytics plays a crucial role in the data-inf...
# 4  It is essential for startups to quickly experi...
#
#                                              summary           published  \
# 0  I describe in this report equity allocation in... 2017-11-02 09:33:44
# 1  # # # # @CNN.com will feature iReporter photos... 2023-04-04 04:21:09
# 2  # # # # @CNN.com will feature iReporter photos... 2021-03-14 19:09:34
# 3  Usman Rafiq is a professor of computer science... 2022-04-11 15:13:33
# ...
